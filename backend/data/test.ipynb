# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
url = "https://www.brfares.com/!expert?orig=ZWS&dest=GTW&period=20250102"

response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-GB">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport">
#    <title>
#     Look up fares for any train journey in Britain
#    </title>
#    <meta content="Full details of all British rail Single, Return &amp; Season tickets and Travelcards. Built-in Season Ticket Calculator." name="description"/>
#    <meta content="" name="robots"/>
#    <link href="brfares.css" rel="stylesheet" type="text/css"/>
#    <link as="font" crossorigin="" href="/fonts/Gibson-Light.woff" rel="preload" type="font/woff"/>
#    <link as="font" crossorigin="" href="/fonts/Gibson-Regular.woff" rel="preload" type="font/woff"/>
#    <script type="text/javascript">
#     var pweb_pd = "";
#     var pweb_tk = "eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9.eyJqdGkiOiIwM2JkZjlkNi1mNmUwLTExZWYtYTdhNS1hZTE5NjI1ODk5ZTgiLCJpc3MiOiJsaWJwd2ViIiwiaWF0IjoxNzQwODYyNzQ2LCJleHAiOjE3NDEyMDgzNDYsInN1YiI6ImJyZmFyZXMifQ.Aqo9z0QxoE8SeFOOjRFPfIeqGUQwUZNCoIX9lo4HM3meF0qEuxxz5uZiQJ1SmK8x2aPAV-yZDHwlW9cVRGXPMlnWiWWaN7kIqx3KIcQ4MouW8JmqLhvJ5GKMbxff_Rr5-g5ecgrfiL4gBa9F0TomQL7MGQHM8y_N2V2oh1Lv5b0RMQdT_sBrHjvWzg_k95YUN1kDH1AkQZqzn28WOn5_HTObDfARWMXad_syWthkppqDY-qphzhMcZxPxbzSDK06ROwedYMff0ZF94hmIwRJG5zpco8HG5h-YK0jBw883TNOtX6Y-Bo2zO0lVO0MRjNdsm5PdqnizU0apFeBRZ95_A";
#    </script>
#    <script src="jq.js" type="text/javascript">
#    </script>
#    <script src="jqui.js" type="text/javascript">
#    </script>
#    <script src="brfaresJScore.js" type="text/javascript">
#    </script>
#    <script src="brfaresapp.js" type="text/javascript">
#    </script>
#    <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#    </script>
#    <script async="" src="//www.googletagmanager.com/gtag/js?id=G-VLNBF701X3">
#    </script>
#    <meta content="br-fares-icon-512x512.png" property="og:image">
#     <link href="br-fares-icon-512x512.png" rel="icon" sizes="512x512" type="image/png">
#      <link href="br-fares-icon-64x64.png" rel="icon" sizes="64x64" type="image/png">
#       <link href="br-fares-icon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#      </link>
#     </link>
#    </meta>
#   </meta>
#  </head>
#  <body>
#   <div class="linkbar_outer">
#    <div class="linkbar_left">
#     <div class="linkbarele">
#      <a href="https://www.brfares.com/">
#       BR
#       <b>
#        FARES
#       </b>
#      </a>
#     </div>
#     <div class="linkbarele">
#      <a href="https://www.brtimes.com/">
#       BR
#       <b>
#        TIMES
#       </b>
#      </a>
#     </div>
#     <div class="linkbarele">
#      <a href="https://www.ltfares.com/">
#       LT
#       <b>
#        FARES
#       </b>
#      </a>
#     </div>
#    </div>
#    <div class="linkbar_right">
#     <div class="linkbarele">
#      <a href="/api/">
#       APIs
#      </a>
#     </div>
#     <div class="linkbarele">
#      <a href="https://blog.brfares.com/">
#       BLOG
#      </a>
#     </div>
#    </div>
#    <hr class="linkbar"/>
#   </div>
#   <div style="width: 100%;">
#    <div id="new_top">
#    </div>
#   </div>
#   <table border="0" cellpadding="5" class="center">
#    <tr>
#     <td align="right" valign="top">
#      <a href="!home">
#       <img alt="BR Fares" border="0" height="23" src="br-fares-logo.png" width="129"/>
#      </a>
#     </td>
#     <td align="left" style="color: #4a4a4a;" valign="top">
#      Look up fares for any train journey in Britain
#     </td>
#    </tr>
#   </table>
#   <div class="orangebg" id="inputouter" style="text-align: justify; font-size: 0;">
#    <div style="display:inline-block;">
#    </div>
#    <div id="inputarea" style="display:inline-block; vertical-align: top; font-size: 1rem; margin: 3px; min-width: 320px; min-height: 102px;">
#    </div>
#    <div id="new_top_box" style="display:inline-block; vertical-align: top; font-size: 1rem;">
#    </div>
#    <div style="display:inline-block;">
#    </div>
#    <span style="display:inline-block; width: 100%;">
#    </span>
#   </div>
#   <div class="outer" style="height: 25px;">
#    <div id="backlink" style="float: right; height: 25px; margin-top: 10px; margin-bottom: 5px;">
#    </div>
#   </div>
#   <div style="text-align: center; width: 100%; margin-top: 10px;">
#    <div class="center" id="textad">
#    </div>
#   </div>
#   <div style="text-align: justify; font-size: 0;">
#    <div style="display:inline-block;">
#    </div>
#    <div style="display:inline-block; vertical-align: top; font-size: 1rem; margin-left: 4px; margin-right: 4px; max-width: 728px;">
#     <div class="center" id="new_under">
#     </div>
#     <div class="center" id="results" style="min-height: 300px;">
#     </div>
#     <div class="consentpanel" id="consent">
#     </div>
#     <table border="0" cellpadding="3" class="center">
#      <tr>
#       <td id="copyright">
#       </td>
#      </tr>
#      <tr>
#       <td align="center">
#        <div id="new_bottom">
#        </div>
#       </td>
#      </tr>
#     </table>
#    </div>
#    <div id="new_side" style="display:inline-block; font-size: 1rem;">
#    </div>
#    <div style="display:inline-block;">
#    </div>
#    <span style="display:inline-block; width: 100%;">
#    </span>
#   </div>
#  </body>
# </html>
